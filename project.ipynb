# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class myLinearRegretion:
    def __init__(self):
        self.m=None
        self.b=None
    def fit(self,x,y):
        num=0
        den=0
        for i in range(x.shape[0]):
            num=num+(x[i]-x.mean())*(y[i]*y.mean)
            den=den+np.square(x[i]-x.mean())
        self.m=num/den
        self.b=y.mean()-m*x.mean()
    
    def predict(self,x):
# Out:
#   Cell In[4], line 6
#     for i in range(x.)
#                      ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv('dataset.csv')

# %%
df.shape[0]
df.loc[:32]
# Out:
#                              MS_SubClass                     MS_Zoning  \
# 0    One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 1    One_Story_1946_and_Newer_All_Styles      Residential_High_Density
# 2    One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 3    One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 4               Two_Story_1946_and_Newer       Residential_Low_Density
# 5               Two_Story_1946_and_Newer       Residential_Low_Density
# 6           One_Story_PUD_1946_and_Newer       Residential_Low_Density
# 7           One_Story_PUD_1946_and_Newer       Residential_Low_Density
# 8           One_Story_PUD_1946_and_Newer       Residential_Low_Density
# 9               Two_Story_1946_and_Newer       Residential_Low_Density
# 10              Two_Story_1946_and_Newer       Residential_Low_Density
# 11   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 12              Two_Story_1946_and_Newer       Residential_Low_Density
# 13   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 14          One_Story_PUD_1946_and_Newer       Residential_Low_Density
# 15              Two_Story_1946_and_Newer       Residential_Low_Density
# 16  One_and_Half_Story_Finished_All_Ages       Residential_Low_Density
# 17   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 18   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 19   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 20   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 21                           Split_Foyer       Residential_Low_Density
# 22              Two_Story_1946_and_Newer  Floating_Village_Residential
# 23   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 24   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 25   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 26   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 27   One_Story_1946_and_Newer_All_Styles       Residential_Low_Density
# 28          One_Story_PUD_1946_and_Newer      Residential_High_Density
# 29          Two_Story_PUD_1946_and_Newer    Residential_Medium_Density
# 30          Two_Story_PUD_1946_and_Newer    Residential_Medium_Density
# 31          Two_Story_PUD_1946_and_Newer    Residential_Medium_Density
# 32          One_Story_PUD_1946_and_Newer       Residential_Low_Density
#
#     Lot_Frontage  Lot_Area Street            Alley             Lot_Shape  \
# 0          141.0   31770.0   Pave  No_Alley_Access    Slightly_Irregular
# 1           80.0   11622.0   Pave  No_Alley_Access               Regular
# 2           81.0   14267.0   Pave  No_Alley_Access    Slightly_Irregular
# 3           93.0   11160.0   Pave  No_Alley_Access               Regular
# 4           74.0   13830.0   Pave  No_Alley_Access    Slightly_Irregular
# 5           78.0    9978.0   Pave  No_Alley_Access    Slightly_Irregular
# 6           41.0    4920.0   Pave  No_Alley_Access               Regular
# 7           43.0    5005.0   Pave  No_Alley_Access    Slightly_Irregular
# 8           39.0    5389.0   Pave  No_Alley_Access    Slightly_Irregular
# 9           60.0    7500.0   Pave  No_Alley_Access               Regular
# 10          75.0   10000.0   Pave  No_Alley_Access    Slightly_Irregular
# 11           0.0    7980.0   Pave  No_Alley_Access    Slightly_Irregular
# 12          63.0    8402.0   Pave  No_Alley_Access    Slightly_Irregular
# 13          85.0   10176.0   Pave  No_Alley_Access               Regular
# 14           0.0    6820.0   Pave  No_Alley_Access    Slightly_Irregular
# 15          47.0   53504.0   Pave  No_Alley_Access  Moderately_Irregular
# 16         152.0   12134.0   Pave  No_Alley_Access    Slightly_Irregular
# 17          88.0   11394.0   Pave  No_Alley_Access               Regular
# 18         140.0   19138.0   Pave  No_Alley_Access               Regular
# 19          85.0   13175.0   Pave  No_Alley_Access               Regular
# 20         105.0   11751.0   Pave  No_Alley_Access    Slightly_Irregular
# 21          85.0   10625.0   Pave  No_Alley_Access               Regular
# 22           0.0    7500.0   Pave  No_Alley_Access               Regular
# 23           0.0   11241.0   Pave  No_Alley_Access    Slightly_Irregular
# 24           0.0   12537.0   Pave  No_Alley_Access    Slightly_Irregular
# 25          65.0    8450.0   Pave  No_Alley_Access               Regular
# 26          70.0    8400.0   Pave  No_Alley_Access               Regular
# 27          70.0   10500.0   Pave  No_Alley_Access               Regular
# 28          26.0    5858.0   Pave  No_Alley_Access    Slightly_Irregular
# 29          21.0    1680.0   Pave  No_Alley_Access               Regular
# 30          21.0    1680.0   Pave  No_Alley_Access               Regular
# 31          21.0    1680.0   Pave  No_Alley_Access               Regular
# 32          53.0    4043.0   Pave  No_Alley_Access               Regular
#
#    Land_Contour Utilities Lot_Config  ...            Fence Misc_Feature  \
# 0           Lvl    AllPub     Corner  ...         No_Fence          NaN
# 1           Lvl    AllPub     Inside  ...  Minimum_Privacy          NaN
# 2           Lvl    AllPub     Corner  ...         No_Fence         Gar2
# 3           Lvl    AllPub     Corner  ...         No_Fence          NaN
# 4           Lvl    AllPub     Inside  ...  Minimum_Privacy          NaN
# 5           Lvl    AllPub     Inside  ...         No_Fence          NaN
# 6           Lvl    AllPub     Inside  ...         No_Fence          NaN
# 7           HLS    AllPub     Inside  ...         No_Fence          NaN
# 8           Lvl    AllPub     Inside  ...         No_Fence          NaN
# 9           Lvl    AllPub     Inside  ...         No_Fence          NaN
# 10          Lvl    AllPub     Corner  ...         No_Fence          NaN
# 11          Lvl    AllPub     Inside  ...     Good_Privacy         Shed
# 12          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 13          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 14          Lvl    AllPub     Corner  ...         No_Fence          NaN
# 15          HLS    AllPub    CulDSac  ...         No_Fence          NaN
# 16          Bnk    AllPub     Inside  ...         No_Fence          NaN
# 17          Lvl    AllPub     Corner  ...         No_Fence          NaN
# 18          Lvl    AllPub     Corner  ...         No_Fence          NaN
# 19          Lvl    AllPub     Inside  ...  Minimum_Privacy          NaN
# 20          Lvl    AllPub     Inside  ...  Minimum_Privacy          NaN
# 21          Lvl    AllPub     Inside  ...  Minimum_Privacy          NaN
# 22          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 23          Lvl    AllPub    CulDSac  ...         No_Fence         Shed
# 24          Lvl    AllPub    CulDSac  ...         No_Fence          NaN
# 25          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 26          Lvl    AllPub     Corner  ...  Minimum_Privacy          NaN
# 27          Lvl    AllPub        FR2  ...         No_Fence          NaN
# 28          Lvl    AllPub        FR2  ...         No_Fence          NaN
# 29          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 30          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 31          Lvl    AllPub     Inside  ...         No_Fence          NaN
# 32          Lvl    AllPub     Inside  ...         No_Fence          NaN
#
#    Misc_Val Mo_Sold Year_Sold Sale_Type Sale_Condition Sale_Price  Longitude  \
# 0       0.0     5.0    2010.0       WD          Normal   215000.0 -93.619754
# 1       0.0     6.0    2010.0       WD          Normal   105000.0 -93.619756
# 2   12500.0     6.0    2010.0       WD          Normal   172000.0 -93.619387
# 3       0.0     4.0    2010.0       WD          Normal   244000.0 -93.617320
# 4       0.0     3.0    2010.0       WD          Normal   189900.0 -93.638933
# 5       0.0     6.0    2010.0       WD          Normal   195500.0 -93.638925
# 6       0.0     4.0    2010.0       WD          Normal   213500.0 -93.633792
# 7       0.0     1.0    2010.0       WD          Normal   191500.0 -93.633826
# 8       0.0     3.0    2010.0       WD          Normal   236500.0 -93.632852
# 9       0.0     6.0    2010.0       WD          Normal   189000.0 -93.639068
# 10      0.0     4.0    2010.0       WD          Normal   175900.0 -93.636947
# 11    500.0     3.0    2010.0       WD          Normal   185000.0 -93.635951
# 12      0.0     5.0    2010.0       WD          Normal   180400.0 -93.638647
# 13      0.0     2.0    2010.0       WD          Normal   171500.0 -93.634626
# 14      0.0     6.0    2010.0       WD          Normal   212000.0 -93.632913
# 15      0.0     6.0    2010.0       WD          Normal   538000.0 -93.626550
# 16      0.0     6.0    2010.0       WD          Normal   164000.0 -93.623595
# 17      0.0     6.0    2010.0       New        Partial   394432.0 -93.628804
# 18      0.0     6.0    2010.0       WD          Normal   141000.0 -93.622971
# 19      0.0     2.0    2010.0       WD          Normal   210000.0 -93.636655
# 20      0.0     1.0    2010.0       COD         Normal   190000.0 -93.633962
# 21      0.0     1.0    2010.0       WD          Family   170000.0 -93.636372
# 22      0.0     1.0    2010.0       WD          Normal   216000.0 -93.639366
# 23    700.0     3.0    2010.0       WD          Normal   149000.0 -93.626231
# 24      0.0     4.0    2010.0       WD          Normal   149900.0 -93.626537
# 25      0.0     7.0    2010.0       WD          Normal   142000.0 -93.628806
# 26      0.0     4.0    2010.0       WD          Normal   126000.0 -93.627112
# 27      0.0     4.0    2010.0     ConLI         Normal   115000.0 -93.622769
# 28      0.0     6.0    2010.0       WD          Normal   184000.0 -93.624373
# 29      0.0     2.0    2010.0       COD         Normal    96000.0 -93.627271
# 30      0.0     3.0    2010.0       WD          Normal   105500.0 -93.627536
# 31      0.0     3.0    2010.0       WD          Family    88000.0 -93.627280
# 32      0.0     7.0    2010.0       WD          Normal   127500.0 -93.627232
#
#      Latitude
# 0   42.054035
# 1   42.053014
# 2   42.052659
# 3   42.051245
# 4   42.060899
# 5   42.060779
# 6   42.062978
# 7   42.060728
# 8   42.061120
# 9   42.059193
# 10  42.058480
# 11  42.057419
# 12  42.058151
# 13  42.057268
# 14  42.059169
# 15  42.061239
# 16  42.060351
# 17  42.058850
# 18  42.056673
# 19  42.054453
# 20  42.050346
# 21  42.050270
# 22  42.049297
# 23  42.055147
# 24  42.054592
# 25  42.055227
# 26  42.053395
# 27  42.056375
# 28  42.055318
# 29  42.051835
# 30  42.051684
# 31  42.051685
# 32  42.049672
#
# [33 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# MS_SubClass       0
# MS_Zoning         0
# Lot_Frontage      0
# Lot_Area          0
# Street            0
#                  ..
# Sale_Type         0
# Sale_Condition    0
# Sale_Price        0
# Longitude         0
# Latitude          0
# Length: 81, dtype: int64

# %%
df[df.isnull().sum()>0]
# Out:
# /tmp/ipykernel_9120/461471528.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.isnull().sum()>0]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[df.isnull().sum()>0]
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pandas/core/frame.py:4369, in DataFrame.__getitem__(self, key)
#    4367 # Do we have a (boolean) 1d indexer?
#    4368 if com.is_bool_indexer(key):
# -> 4369     return self._getitem_bool_array(key)
#    4371 # We are left with two options: a single key, and a collection of keys,
#    4372 # We interpret tuples as collections only for non-MultiIndex
#    4373 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pandas/core/frame.py:4425, in DataFrame._getitem_bool_array(self, key)
#    4419     raise ValueError(
#    4420         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    4421     )
#    4423 # check_bool_indexer will throw exception if Series key cannot
#    4424 # be reindexed to match DataFrame rows
# -> 4425 key = check_bool_indexer(self.index, key)
#    4427 if key.all():
#    4428     return self.copy(deep=False)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pandas/core/indexing.py:2677, in check_bool_indexer(index, key)
#    2675 indexer = result.index.get_indexer_for(index)
#    2676 if -1 in indexer:
# -> 2677     raise IndexingError(
#    2678         "Unalignable boolean Series provided as "
#    2679         "indexer (index of the boolean Series and of "
#    2680         "the indexed object do not match)."
#    2681     )
#    2683 result = result.take(indexer)
#    2685 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
